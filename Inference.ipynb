# %%
from detect.yolo.inference import run, run_per_img
from models.common import DetectMultiBackend
import torch
# Out:
# /Users/maochenhui/miniforge3/envs/DL/lib/python3.8/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# Loading weights from deep_sort/deep/checkpoint/ckpt.t7... Done!

# %% [markdown]
# # Fed with live videos

# %%
import cv2
data = "./data/custom.yaml"
weights = "./runs/train/yolov5n/weights/best.pt"
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model = DetectMultiBackend(weights, device=device, data=data)

source = "./data/dataset/Fall_Detection_Object/Test/Fall_Person_valid_000000.png"
img = cv2.imread(source)
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (416, 416))

view_img = True

frame = run_per_img(model, img, device, view_img=view_img)

# %%
from detect.yolo.inference import live_inference_fed_img

weights = "./runs/train/yolov5n/weights/best.pt"
source = 0
source = "./runs/detect/exp/FALL_DEMO.mp4"
data = "./data/custom.yaml"
out_name = "Walk"
imgsz = (416, 416)
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
live_inference_fed_img(weights=weights,
               source=source, 
               data=data,
               out_name=out_name,
               detect=True,
               tracking=False,
               save_txt=False,
               view_img=True,
               save_crop=False, 
               conf_thres=0.25)
# Out:
# Detect Finished

# %% [markdown]
# # Fed with Image files

# %%
weights = "./runs/train/yolov5n/weights/best.pt"
source = "./data/dataset/Fall_Detection_Object/Test/Fall_Person_valid_000000.png"
data = "./data/custom.yaml"
imgsz = (416, 416)
view_img = True

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model = DetectMultiBackend(weights, device=device, data=data)
run(model, device, source=source, imgsz=imgsz, view_img=view_img)
# Out:
# array([[[ 98, 103, 106],
#         [ 97, 103, 106],
#         [104, 112, 113],
#         ...,
#         [ 95,  97, 105],
#         [ 98,  99, 108],
#         [100, 102, 111]],
#
#        [[ 95, 100, 104],
#         [ 98, 104, 107],
#         [103, 110, 113],
#         ...,
#         [ 96,  97, 106],
#         [ 99, 101, 109],
#         [ 97,  99, 107]],
#
#        [[ 94,  99, 102],
#         [ 98, 104, 108],
#         [102, 110, 113],
#         ...,
#         [101, 103, 111],
#         [ 98, 100, 108],
#         [ 97,  98, 107]],
#
#        ...,
#
#        [[149, 180, 190],
#         [151, 183, 192],
#         [156, 190, 198],
#         ...,
#         [ 58,  71,  94],
#         [ 54,  57,  72],
#         [ 53,  54,  65]],
#
#        [[153, 186, 195],
#         [158, 192, 200],
#         [159, 193, 200],
#         ...,
#         [ 60,  76,  99],
#         [ 51,  55,  72],
#         [ 50,  51,  63]],
#
#        [[159, 193, 202],
#         [161, 195, 203],
#         [160, 194, 201],
#         ...,
#         [ 67,  83, 107],
#         [ 48,  53,  70],
#         [ 55,  55,  69]]], dtype=uint8)

# %%
from detect.yolo.inference import live_inference

weights = "./runs/train/yolov5n/weights/best.pt"
# source = "./runs/detect/exp/result.mp4"
source = 0
data = "./data/custom.yaml"
out_name = "Walk"
imgsz = (416, 416)
conf_thres=0.25
view_img = True
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
live_inference(weights=weights, 
               source=source, 
               data=data,
               out_name=out_name, 
               view_img=True, 
               save_crop=True, 
               conf_thres=0.5)
# Out:
# Fusing layers...
# Model Summary: 213 layers, 1760518 parameters, 0 gradients
# WARNING: --img-size (416, 416) must be multiple of max stride 32, updating to [416, 416]
# Detect Finished
