# %%
from detect.yolo.inference import run
from models.common import DetectMultiBackend
import torch
# Out:
# /Users/maochenhui/miniforge3/envs/DL/lib/python3.8/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")

# %%
weights = "./runs/train/yolov5n/weights/best.pt"
source = "./data/dataset/Fall_Detection_Object/Test/Fall_Person_valid_000000.png"
data = "./data/custom.yaml"
imgsz = (416, 416)
view_img = True

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model = DetectMultiBackend(weights, device=device, data=data)
run(model, device, source=source, imgsz=imgsz, view_img=view_img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x152D47790>
# array([[[ 98, 103, 106],
#         [ 97, 103, 106],
#         [104, 112, 113],
#         ...,
#         [ 95,  97, 105],
#         [ 98,  99, 108],
#         [100, 102, 111]],
#
#        [[ 95, 100, 104],
#         [ 98, 104, 107],
#         [103, 110, 113],
#         ...,
#         [ 96,  97, 106],
#         [ 99, 101, 109],
#         [ 97,  99, 107]],
#
#        [[ 94,  99, 102],
#         [ 98, 104, 108],
#         [102, 110, 113],
#         ...,
#         [101, 103, 111],
#         [ 98, 100, 108],
#         [ 97,  98, 107]],
#
#        ...,
#
#        [[149, 180, 190],
#         [151, 183, 192],
#         [156, 190, 198],
#         ...,
#         [ 58,  71,  94],
#         [ 54,  57,  72],
#         [ 53,  54,  65]],
#
#        [[153, 186, 195],
#         [158, 192, 200],
#         [159, 193, 200],
#         ...,
#         [ 60,  76,  99],
#         [ 51,  55,  72],
#         [ 50,  51,  63]],
#
#        [[159, 193, 202],
#         [161, 195, 203],
#         [160, 194, 201],
#         ...,
#         [ 67,  83, 107],
#         [ 48,  53,  70],
#         [ 55,  55,  69]]], dtype=uint8)

# %%
from detect.yolo.inference import live_inference

weights = "./runs/train/exp2/weights/best.pt"
# source = "./runs/detect/exp/result.mp4"
source = 0
data = "./data/custom.yaml"
out_name = "Walk"
imgsz = (416, 416)
conf_thres=0.25
view_img = True
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
live_inference(weights=weights, 
               source=source, 
               data=data, 
               device=device, 
               out_name=out_name, 
               view_img=True, 
               save_crop=True, 
               conf_thres=0.5)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x164436CA0>
# Detect Finish

# %%
import glob
import re

def match(x):
    patterns = r"[0-9]+"
    x = x.split("/")[-1]
    idx = re.search(patterns, x).group()
    return int(idx)

files = glob.glob("./runs/detect/exp/crops/person/*.jpg")
files = sorted(files, key=match)
files
# Out:
# ['./runs/detect/exp/crops/person/walk1.jpg',
#  './runs/detect/exp/crops/person/walk2.jpg',
#  './runs/detect/exp/crops/person/walk3.jpg',
#  './runs/detect/exp/crops/person/walk4.jpg',
#  './runs/detect/exp/crops/person/walk5.jpg',
#  './runs/detect/exp/crops/person/walk6.jpg',
#  './runs/detect/exp/crops/person/walk7.jpg',
#  './runs/detect/exp/crops/person/walk8.jpg',
#  './runs/detect/exp/crops/person/walk9.jpg',
#  './runs/detect/exp/crops/person/walk10.jpg',
#  './runs/detect/exp/crops/person/walk11.jpg',
#  './runs/detect/exp/crops/person/walk12.jpg',
#  './runs/detect/exp/crops/person/walk13.jpg',
#  './runs/detect/exp/crops/person/walk14.jpg',
#  './runs/detect/exp/crops/person/walk15.jpg',
#  './runs/detect/exp/crops/person/walk16.jpg',
#  './runs/detect/exp/crops/person/walk17.jpg',
#  './runs/detect/exp/crops/person/walk18.jpg',
#  './runs/detect/exp/crops/person/walk19.jpg',
#  './runs/detect/exp/crops/person/walk20.jpg',
#  './runs/detect/exp/crops/person/walk21.jpg',
#  './runs/detect/exp/crops/person/walk22.jpg',
#  './runs/detect/exp/crops/person/walk23.jpg',
#  './runs/detect/exp/crops/person/walk24.jpg',
#  './runs/detect/exp/crops/person/walk25.jpg',
#  './runs/detect/exp/crops/person/walk26.jpg',
#  './runs/detect/exp/crops/person/walk27.jpg']
